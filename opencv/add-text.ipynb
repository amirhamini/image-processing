# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t

# %% [markdown]
# ** Read and show**

# %%
img = cv2.imread('./pic/IMG_0030.JPG', 1) #1 gives a gray picture

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# **Crop**

# %%
y_up = 1000; y_down = 3000; h = y_down - y_up;
x_left = 1500; x_right = 4000; w = x_right - x_left;
crop_img = img[y_up:y_down, x_left:x_right]
plt.imshow(crop_img)
plt.show()

# %% [markdown]
# **Save**

# %%
#cv2.imwrite('./pic/cropped.jpg',crop_img)

# %% [markdown]
# **Add text**

# %%
img = cv2.imread('./pic/IMG_0030.JPG', 1) #1 gives a gray picture
#
y_up = 1000; y_down = 3000; h = y_down - y_up;
x_left = 1500; x_right = 4000; w = x_right - x_left;
crop_img = img[y_up:y_down, x_left:x_right]
#
font = cv2.FONT_HERSHEY_SIMPLEX
x_txt = 200; y_txt = 200;
clr = 0.5
cv2.putText(crop_img, "Time", (x_txt, y_txt), font, 5,
                        clr, thickness=3)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
plt.imshow(crop_img)
plt.show()

# %%
cv2.imwrite('./pic/cropped.jpg',crop_img)
# Out:
# True
